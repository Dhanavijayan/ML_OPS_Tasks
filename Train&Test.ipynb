# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanavijayan/ML_OPS_Tasks/blob/main/Train%26Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

file_path = "supermarket_sample.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Row_ID  Foot_Traffic  Staff_Count  Hour  High_Value_Items  Shrinkage_INR  \
# 0       1           164            3    16                30            293
# 1       2            62            6    10                89            322
# 2       3           434            6    16                88            870
# 3       4            91            3    20                93            593
# 4       5           298            3    15                33            712
#
#    Predicted_INR  Residual_INR Theft_Level
# 0            330           -37         Low
# 1            174           148         Low
# 2            841            29        High
# 3            476           117      Medium
# 4            579           133        High

# %%
X = df[["Foot_Traffic", "Hour"]]
y = df["Shrinkage_INR"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_test
# Out:
#      Foot_Traffic  Hour
# 201           180    13
# 348           493    18
# 164           490    20
# 455           267    20
# 446           143    11
# ..            ...   ...
# 448           475     9
# 436           334    18
# 464           390    19
# 233           278     9
# 203           232     9
#
# [150 rows x 2 columns]

# %%
y_test
# Out:
# 201     338
# 348    1008
# 164     957
# 455     513
# 446     399
#        ...
# 448     849
# 436     922
# 464     664
# 233     382
# 203     564
# Name: Shrinkage_INR, Length: 150, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([328.87030279, 915.31053702, 929.94038264, 547.35057516,
#        245.61448273, 286.88371951, 892.10244459, 616.600244  ,
#        507.79698775, 168.8157608 , 660.17793367, 820.45067075,
#        626.27044576, 621.34169277, 445.12896002, 465.62310024,
#        778.55773957, 367.83108667, 895.128244  , 821.26166937,
#        214.23364281, 378.71778637, 736.07200486, 618.00404616,
#        536.55752757, 874.04130025, 658.77413151,  71.42924654,
#        365.70993799, 438.57820978, 665.94857615, 902.39634076,
#        618.00404616, 742.34179877, 819.04686859, 241.27853327,
#        901.58534213, 174.55551242, 591.36465501, 572.67981626,
#        424.44751558, 375.50468274, 420.20521823, 594.48410653,
#        824.38112089, 848.30655983, 336.94939817, 776.84209021,
#        428.37796572, 815.61556986, 493.75994566, 140.5543724 ,
#        473.57765264, 483.18509316, 715.20325619, 382.05543298,
#        189.80905245, 677.95812168, 307.78335904, 183.13375923,
# ...

# %%
clf.score(X_test, y_test)
# Out:
# 0.755082428158032

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_test
# Out:
#      Foot_Traffic  Hour
# 151           355    16
# 424           320     8
# 154           493    14
# 190           429    14
# 131           374    17
# ..            ...   ...
# 12            202    10
# 97            201    19
# 130           327    11
# 472           300    11
# 315           355     9
#
# [150 rows x 2 columns]
